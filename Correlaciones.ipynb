# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel353/Act_2_GPPT/blob/main/Correlaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .csv sin indice
Credicel = pd.read_excel('PrepCrit3.xlsx')

# %%
Credicel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22735 entries, 0 to 22734
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tag                 22735 non-null  object
#  1   marca               22735 non-null  object
#  2   modelo              22735 non-null  object
#  3   plazo               22735 non-null  object
#  4   agente_venta        22735 non-null  object
#  5   dis_venta           22735 non-null  object
#  6   empresa             22735 non-null  object
#  7   fecha_ultimo_pago   22735 non-null  object
#  8   fecha_pago_proximo  22735 non-null  object
#  9   status_cuenta       22735 non-null  object
#  10  riesgo              22735 non-null  object
#  11  razones_buro        22735 non-null  object
#  12  semana_actual       22735 non-null  object
#  13  codigo_postal       22735 non-null  object
#  14  folio               22735 non-null  int64
#  15  folio_solicitud     22735 non-null  int64
#  16  descuento           22735 non-null  float64
#  17  monto_accesorios    22735 non-null  float64
#  18  status              22735 non-null  int64
#  19  fraude              22735 non-null  int64
#  20  inversion           22735 non-null  int64
#  21  pagos_realizados    22735 non-null  int64
#  22  reautorizacion      22735 non-null  int64
#  23  puntos              22735 non-null  int64
#  24  porc_enganche       22735 non-null  float64
#  25  porc_tasa           22735 non-null  float64
#  26  score_buro          22735 non-null  float64
#  27  precio              22735 non-null  float64
#  28  costo_total         22735 non-null  float64
#  29  monto_financiado    22735 non-null  float64
#  30  semana              22735 non-null  float64
#  31  enganche            22735 non-null  float64
# dtypes: float64(10), int64(8), object(14)
# memory usage: 5.6+ MB

# %%
#Corroboramos valores nulos
ValoresNulos = Credicel.isnull().sum()
ValoresNulos
# Out:
# tag                   0
# marca                 0
# modelo                0
# plazo                 0
# agente_venta          0
# dis_venta             0
# empresa               0
# fecha_ultimo_pago     0
# fecha_pago_proximo    0
# status_cuenta         0
# riesgo                0
# razones_buro          0
# semana_actual         0
# codigo_postal         0
# folio                 0
# folio_solicitud       0
# descuento             0
# monto_accesorios      0
# status                0
# fraude                0
# inversion             0
# pagos_realizados      0
# reautorizacion        0
# puntos                0
# porc_enganche         0
# porc_tasa             0
# score_buro            0
# precio                0
# costo_total           0
# monto_financiado      0
# semana                0
# enganche              0
# dtype: int64

# %%
#Filtro por objeto (Primer Filtro)
Credicel13Sem = Credicel[Credicel["plazo"] == "13S"]
Credicel13Sem
# Out:
#             tag     marca                         modelo plazo  \
# 1      M418YNR4  MOTOROLA   LTE XT2097-12 E7I POWER Azul   13S
# 2      SZ7V3NZT       ZTE             BLADE A3 2020 Gris   13S
# 3      9I08UIQZ       ZTE             BLADE A3 2020 Gris   13S
# 7      LMC1PBLV  MOTOROLA          LTE XT2128-1 G20 Rosa   13S
# 10     MOTLICPV     NOKIA                1.4 2/32 GRIS B   13S
# ...         ...       ...                            ...   ...
# 22706  BQZO8DO5   Samsung                           A04E   13S
# 22710  MQ4JTKQ9   Samsung                           A04E   13S
# 22714  C65ISWKE   Samsung                            A13   13S
# 22718  L4IMFST4  Motorola                      Moto E22i   13S
# 22725  8OLERMPL       ZTE  BLADE A52 LITE 2+32GB VERDE B   13S
#
#                              agente_venta  dis_venta   empresa  \
# 1                   Alvaro Rafael Pascual     mic015  microtec
# 2         Sintia Verenice Tenorio Perez E    mic0437  microtec
# 3              Luz Aylin Hernandez Lopez1    mic0748  microtec
# 7               Mayra Jazmin Reyes Patino    mic0666  microtec
# 10        Luis Gerardo Almanzar Hernandez    mic0437  microtec
# ...                                   ...        ...       ...
# 22706  Marco Antonio Monterrubio Cuicahua     php007  phonepay
# 22710             Itzel Hernandez Aguilar     svc010  servicel
# 22714                Netza Fierros Mateos     php005  phonepay
# 22718            Lorena Camacho Gutierres  micd20352  texpress
# 22725           Liliana Pacheco VazquezSP     mic015  microtec
#
#          fecha_ultimo_pago   fecha_pago_proximo status_cuenta  ...  \
# 1              Desconocido          Desconocido   Desconocido  ...
# 2              Desconocido          Desconocido   Desconocido  ...
# 3              Desconocido          Desconocido   Desconocido  ...
# 7              Desconocido          Desconocido   Desconocido  ...
# 10     2022-01-22 00:00:00  2022-02-03 00:00:00          Mora  ...
# ...                    ...                  ...           ...  ...
# 22706  2023-04-18 15:24:39  2023-04-25 00:00:00   Desconocido  ...
# 22710  2023-04-18 15:59:02  2023-04-25 00:00:00   Desconocido  ...
# 22714  2023-04-18 16:41:27  2023-04-25 00:00:00   Desconocido  ...
# 22718  2023-04-18 16:54:20  2023-04-25 00:00:00   Desconocido  ...
# 22725  2023-04-18 17:23:13  2023-04-25 00:00:00   Desconocido  ...
#
#       reautorizacion puntos porc_enganche porc_tasa  score_buro   precio  \
# 1                  0     12          0.00      0.00         0.0  2999.00
# 2                  0     12          0.00      0.00         0.0  1959.00
# 3                  0     12          0.00      0.00         0.0  1959.00
# 7                  0     12          0.00      0.00         0.0  3999.00
# 10                 0      0          0.00      0.00         0.0  2599.00
# ...              ...    ...           ...       ...         ...      ...
# 22706              0     12         -7.00     -0.10         0.0  2999.00
# 22710              0     12         34.10     12.12         0.0  3149.00
# 22714              0     12         24.80     -2.30         0.0  5299.00
# 22718              0     12         -6.65      1.00         0.0  3399.00
# 22725              0     12          2.00      3.60         0.0  2572.83
#
#        costo_total  monto_financiado  semana  enganche
# 1           2925.0           1949.00   225.0    1050.0
# 2           2210.0           1469.00   170.0     490.0
# 3           2210.0           1469.00   170.0     490.0
# 7           3744.0           2499.00   288.0    1500.0
# 10          2730.0           1819.00   210.0     780.0
# ...            ...               ...     ...       ...
# 22706       3653.0           2432.00   281.0     567.0
# 22710       3614.0           2409.00   278.0    1137.0
# 22714       6305.0           4202.00   224.5    1097.0
# 22718       4082.0           2719.00   314.0     680.0
# 22725       2951.0           1965.83   235.0     607.0
#
# [6340 rows x 32 columns]

# %%
#Filtro por objeto (Segundo Filtro)
Credicel26Sem = Credicel[Credicel["plazo"] == "26S"]
Credicel26Sem
# Out:
#             tag     marca                        modelo plazo  \
# 0      HDNAWQ3A       ZTE            Blade A3 2020 RO B   26S
# 5      FOBQ8A27  MOTOROLA  LTE XT2097-12 E7I POWER Azul   26S
# 6      UND81DCF  MOTOROLA      E7I POWER 2+32 GB AZUL B   26S
# 8      5SDZN7O1     KODAK          LTE SEREN D60LX Azul   26S
# 9      R523EMQT     NOKIA      NOKIA 2.4 3+64 GB GRIS B   26S
# ...         ...       ...                           ...   ...
# 22729  MEQRYKUR   Samsung                        A53 5G   26S
# 22730  92KQVRIX  Motorola                      Moto E13   26S
# 22731  NWB2EA8J  Motorola                     Moto E22i   26S
# 22732  VDTRJ2W6   Samsung                           A13   26S
# 22734  2CI4N2WS   Samsung                        A22 5G   26S
#
#                            agente_venta dis_venta      empresa  \
# 0       Sintia Verenice Tenorio Perez E   mic0437     microtec
# 5         Karim Hassan Mendez Animas GP   mic0569     microtec
# 6       Luis Gerardo Almanzar Hernandez   mic0437     microtec
# 8       Luis Gerardo Almanzar Hernandez   mic0437     microtec
# 9             Rita Dalia Morales Flores    mic08q     microtec
# ...                                 ...       ...          ...
# 22729        Jose Arturo Colchado Lopez    ccl004    centrocel
# 22730  Mildred Asuncion Arguello Caamal    svc044     servicel
# 22731      Maria Guadalupe Vargas Lopez    PXC004  pixelulares
# 22732        NicolÃ¡s JimÃ©nez SÃ¡nchez    gph008  Desconocido
# 22734              Netza Fierros Mateos    php005     phonepay
#
#          fecha_ultimo_pago   fecha_pago_proximo status_cuenta  ...  \
# 0              Desconocido          Desconocido   Desconocido  ...
# 5              Desconocido          Desconocido   Desconocido  ...
# 6              Desconocido          Desconocido   Desconocido  ...
# 8              Desconocido          Desconocido   Desconocido  ...
# 9      2022-09-03 00:00:00  2022-12-06 00:00:00          Mora  ...
# ...                    ...                  ...           ...  ...
# 22729  2023-04-18 17:45:18  2023-04-25 00:00:00   Desconocido  ...
# 22730  2023-04-18 18:45:00  2023-04-25 00:00:00   Desconocido  ...
# 22731  2023-04-18 18:46:53  2023-04-25 00:00:00   Desconocido  ...
# 22732  2023-04-18 18:47:47  2023-04-25 00:00:00   Desconocido  ...
# 22734  2023-04-18 18:49:39  2023-04-25 00:00:00   Desconocido  ...
#
#       reautorizacion puntos porc_enganche porc_tasa  score_buro  precio  \
# 0                  0     12          0.00      0.00         0.0  1949.0
# 5                  0     12          0.00      0.00         0.0  2999.0
# 6                  0     12          0.00      0.00         0.0  2999.0
# 8                  0     12          0.00      0.00         0.0  2889.0
# 9                  0      0          0.00      0.00         0.0  2999.0
# ...              ...    ...           ...       ...         ...     ...
# 22729              0     12         26.25      3.57         0.0  3935.5
# 22730              0     12         27.40     -1.13         0.0  3349.0
# 22731              0     12         19.00      7.48         0.0  4100.0
# 22732              0     12         26.65      0.75         0.0  4849.0
# 22734              0     12         21.80     -2.88         0.0  5399.0
#
#        costo_total  monto_financiado  semana  enganche
# 0           2106.0            1169.0    81.0     780.0
# 5           4056.0            2249.0   156.0     750.0
# 6           3770.0            2099.0   145.0     900.0
# 8           3406.0            1889.0   131.0    1000.0
# 9           4056.0            2249.0   156.0     750.0
# ...            ...               ...     ...       ...
# 22729       7202.0            4000.0   277.0     866.9
# 22730       5486.0            3052.0   211.0     297.0
# 22731       5200.0            2891.0   200.0    1209.0
# 22732       6656.0            3697.0   256.0    1152.0
# 22734       7774.0            4313.0   299.0    1086.0
#
# [10663 rows x 32 columns]

# %%
#Filtro por objeto (Tercer Filtro)
Credicel39Sem = Credicel[Credicel["plazo"] == "39S"]
Credicel39Sem
# Out:
#             tag     marca                      modelo plazo  \
# 4      JMF4LKYU  MOTOROLA                       G10 B   39S
# 29     O67CJR7N  MOTOROLA       LTE XT2128-1 G20 Rosa   39S
# 32     4VK0M9IK  MOTOROLA                       G10 B   39S
# 43     MM9SOZBD  MOTOROLA       LTE XT2128-1 G20 Rosa   39S
# 46     TUHZX7WI  MOTOROLA       LTE XT2053-5 E6I Rosa   39S
# ...         ...       ...                         ...   ...
# 22722  F43OIVKM  MOTOROLA                    MOTO G31   39S
# 22724  RTBMD1Z2  Motorola                    Moto E32   39S
# 22726  WAWTRVCS  MOTOROLA  MOTO G51 5G 4+128GB AZUL B   39S
# 22728  X4AXNZBG  Motorola                   Moto E22i   39S
# 22733  PETLF56C   Samsung                      A53 5G   39S
#
#                           agente_venta  dis_venta    empresa  \
# 4      Sintia Verenice Tenorio Perez E    mic0437   microtec
# 29           Linda Mariluz Ruiz Luna G    mic0748   microtec
# 32           Ana Line Garcia Hernandez    mic0758   microtec
# 43           Ana Line Garcia Hernandez    mic0758   microtec
# 46           Ana Line Garcia Hernandez    mic0758   microtec
# ...                                ...        ...        ...
# 22722           Luz Maria Sotelo Roman     arc008  arcelular
# 22724           Selena Gomez Hernandez     rwc010   redworld
# 22726  Sintia Verenice Tenorio Perez E    mic0437   microtec
# 22728         Lorena Camacho Gutierres  micd20352   texpress
# 22733          Maribel Ulibarri Medina     gph014    grupoph
#
#          fecha_ultimo_pago   fecha_pago_proximo status_cuenta  ...  \
# 4      2022-03-05 00:00:00  2022-03-12 00:00:00          Mora  ...
# 29     2022-07-07 00:00:00  2022-08-10 00:00:00          Mora  ...
# 32             Desconocido          Desconocido   Desconocido  ...
# 43             Desconocido          Desconocido   Desconocido  ...
# 46     2023-04-07 00:00:00  2023-04-15 00:00:00        Atraso  ...
# ...                    ...                  ...           ...  ...
# 22722  2023-04-18 17:05:50  2023-04-25 00:00:00   Desconocido  ...
# 22724  2023-04-18 17:15:43  2023-04-25 00:00:00   Desconocido  ...
# 22726  2023-04-18 17:30:00  2023-04-25 00:00:00   Desconocido  ...
# 22728  2023-04-18 17:33:19  2023-04-25 00:00:00   Desconocido  ...
# 22733  2023-04-18 18:49:08  2023-04-25 00:00:00   Desconocido  ...
#
#       reautorizacion puntos porc_enganche porc_tasa  score_buro   precio  \
# 4                  0      0          0.00      0.00         0.0  4299.00
# 29                 0      0          0.00      0.00         0.0  4599.00
# 32                 0     12          0.00      0.00         0.0  4299.00
# 43                 0     12          0.00      0.00         0.0  4599.00
# 46                 0      0          0.00      0.00         0.0  2699.00
# ...              ...    ...           ...       ...         ...      ...
# 22722              0     12         27.45      1.40         0.0  4749.00
# 22724              0     12          1.75     -0.90         0.0  3799.00
# 22726              0     12         41.10      4.50         0.0  5698.86
# 22728              0     12         26.35      0.13         0.0  3499.00
# 22733              0     12        -17.35     -0.14         0.0  3935.50
#
#        costo_total  monto_financiado  semana  enganche
# 4           6942.0           3224.00   178.0    1075.0
# 29          7410.0           3449.00   190.0    1150.0
# 32          6474.0           3009.00   166.0    1290.0
# 43          6903.0           3219.00   177.0    1380.0
# 46          4056.0           1889.00   104.0     810.0
# ...            ...               ...     ...       ...
# 22722       9048.0           4208.00   232.0     541.0
# 22724       6591.0           3073.00   169.0     726.0
# 22726      10491.0           4872.86   284.0     826.0
# 22728       6747.0           3145.00   173.0     354.0
# 22733       5448.5           3001.80   386.0     866.9
#
# [5282 rows x 32 columns]

# %%
#Filtro por objeto (Tercer Filtro)
Credicel52Sem = Credicel[Credicel["plazo"] == "52S"]
Credicel52Sem
# Out:
#             tag     marca                         modelo plazo  \
# 44     VNOHNLYD  MOTOROLA       E7I POWER 2+32 GB ROJO B   52S
# 55     BTSUUV1H        LG                     K52 B AZUL   52S
# 60     D7PIKQPF       ZTE        LTE BLADE A51 64GB Gris   52S
# 68     PG4QNXP4  MOTOROLA          LTE XT2128-1 G20 Rosa   52S
# 151    MO4WVC16  MOTOROLA       E7I POWER 2+32 GB AZUL B   52S
# ...         ...       ...                            ...   ...
# 18615  WASTKJFB   Samsung                            A04   52S
# 18747  P538CSMO       TCL                      6125F 20E   52S
# 19187  TZJJN5IN       ZTE  BLADE A52 LITE 2+32GB VERDE B   52S
# 19386  Y6NV9HBT  Motorola                    Moto G51 5G   52S
# 20127  VONHY9GR   SAMSUNG      GALAXY A03 4+64 GB AZUL B   52S
#
#                          agente_venta dis_venta      empresa  \
# 44          Ana Line Garcia Hernandez   mic0758     microtec
# 55          Ana Line Garcia Hernandez   mic0758     microtec
# 60           Rodolfo Rodriguez Juarez     mic09     microtec
# 68          Rita Dalia Morales Flores    mic08q     microtec
# 151       Luis Gustavo Simon Cristino    mic08q     microtec
# ...                               ...       ...          ...
# 18615  Jose Francisco Martinez Aviles    mun002  comunicatec
# 18747    Jose Gregorio Madrid Dolores   acel008    apartacel
# 19187          Roberto Bautista Perez     mic09     microtec
# 19386       Gissel VillaseÃ±or Flores    lnt003     linetelc
# 20127  Evelyn Yazmin Rodriguez Garcia    mic01A     microtec
#
#          fecha_ultimo_pago   fecha_pago_proximo status_cuenta  ...  \
# 44     2022-05-16 00:00:00  2022-05-24 00:00:00          Mora  ...
# 55     2023-03-10 00:00:00  2023-03-17 00:00:00        Atraso  ...
# 60     2023-04-15 00:00:00  2023-04-22 00:00:00     Corriente  ...
# 68     2023-04-14 00:00:00  2023-04-23 00:00:00     Corriente  ...
# 151            Desconocido          Desconocido   Desconocido  ...
# ...                    ...                  ...           ...  ...
# 18615  2023-04-20 00:00:00  2023-04-27 00:00:00     Corriente  ...
# 18747  2023-03-06 00:00:00  2023-03-13 00:00:00        Fraude  ...
# 19187  2023-03-10 00:00:00  2023-03-17 00:00:00        Fraude  ...
# 19386  2023-03-05 00:00:00  2023-03-12 00:00:00        Fraude  ...
# 20127  2023-04-12 00:00:00  2023-04-20 00:00:00     Corriente  ...
#
#       reautorizacion puntos porc_enganche porc_tasa  score_buro   precio  \
# 44                 0      0          0.00       0.0         0.0  2999.00
# 55                 0      0          0.00       0.0         0.0  3999.00
# 60                 0      0          0.00       0.0         0.0  2999.00
# 68                 0      0          0.00       0.0         0.0  4599.00
# 151                1     12          0.00       0.0         0.0  3508.83
# ...              ...    ...           ...       ...         ...      ...
# 18615              0      2          3.93       0.0         0.0  3019.00
# 18747              0      8          5.28       0.0         0.0  2999.00
# 19187              0      4          0.38       0.0         0.0  2572.83
# 19386              0     11          1.38       0.0         0.0  7549.00
# 20127              0     11          0.50       0.0         0.0  3793.85
#
#        costo_total  monto_financiado  semana  enganche
# 44          5824.0           2249.00   112.0     750.0
# 55          7280.0           2799.00   140.0    1200.0
# 60          5824.0           2249.00   112.0     750.0
# 68          8944.0           3449.00   172.0    1150.0
# 151         6864.0           2631.83   132.0     877.0
# ...            ...               ...     ...       ...
# 18615       6760.0           2598.00   130.0     421.0
# 18747       6604.0           2541.00   127.0     458.0
# 19187       5980.0           2305.83   115.0     267.0
# 19386       5448.5           3001.80   334.0     859.0
# 20127       8840.0           3395.85   170.0     398.0
#
# [450 rows x 32 columns]

# %% [markdown]
# ### 13 Semanas
# Correlación y modelo

# %%
# Scatter plot entre la variable dependiente (total) e independientes
# Comportamiento de su dispersión

from turtle import color

sns.scatterplot(x = 'enganche', y = 'precio', color = 'blue', data = Credicel13Sem)
# Out:
# <Axes: xlabel='enganche', ylabel='precio'>

# %%
# Variable Dependiente e Independiente

Var_Indep = Credicel13Sem[['enganche']]
Var_Dep = Credicel13Sem['precio']

# %%
# Se define model como la función de regresión lineal

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
# Ajustamos el modelo con las variables declaradas
model.fit(X = Var_Indep, y = Var_Dep)
# X debe ser mayúscula para la variable independiente
# Out:
# LinearRegression()

# %%
# Verificamos los coeficientes obtenidos para el modelo ajustado

model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['enganche'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([2.51790115]),
#  'rank_': 1,
#  'singular_': array([25188.31983499]),
#  'intercept_': 1518.1489177381582}

# %% [markdown]
# Modelo Matemático (Precio vs Enganche): y = 2.51790115x1 + 1518.1489177381582

# %%
# Corroboramos cual es el coeficiente de Determinación de nuestro modelo

coef_Deter = model.score(X = Var_Indep, y = Var_Dep)
coef_Deter
# Out:
# 0.4291330442155672

# %%
# Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl = np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.6550824713084354

# %%
# Scatter plot entre la variable dependiente (total) e independientes
# Comportamiento de su dispersión

from turtle import color

sns.scatterplot(x = 'monto_financiado', y = 'precio', color = 'blue', data = Credicel13Sem)
# Out:
# <Axes: xlabel='monto_financiado', ylabel='precio'>

# %%
# Variable Dependiente e Independiente

Var_Indep = Credicel13Sem[['monto_financiado']]
Var_Dep = Credicel13Sem['precio']

# %%
# Se define model como la función de regresión lineal

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
# Ajustamos el modelo con las variables declaradas
model.fit(X = Var_Indep, y = Var_Dep)
# X debe ser mayúscula para la variable independiente
# Out:
# LinearRegression()

# %%
# Verificamos los coeficientes obtenidos para el modelo ajustado

model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['monto_financiado'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([1.17376905]),
#  'rank_': 1,
#  'singular_': array([75451.71622767]),
#  'intercept_': 420.6825824665907}

# %% [markdown]
# Modelo Matemático (Precio vs Monto Financiado): y = 1.17376905x1 + 420.6825824665907

# %%
# Corroboramos cual es el coeficiente de Determinación de nuestro modelo

coef_Deter = model.score(X = Var_Indep, y = Var_Dep)
coef_Deter
# Out:
# 0.8367963157081435

# %%
# Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl = np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.9147657162946934

# %%
# Scatter plot entre la variable dependiente (total) e independientes
# Comportamiento de su dispersión

from turtle import color

sns.scatterplot(x = 'costo_total', y = 'precio', color = 'blue', data = Credicel13Sem)
# Out:
# <Axes: xlabel='costo_total', ylabel='precio'>

# %%
# Variable Dependiente e Independiente

Var_Indep = Credicel13Sem[['costo_total']]
Var_Dep = Credicel13Sem['precio']

# %%
# Se define model como la función de regresión lineal

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
# Ajustamos el modelo con las variables declaradas
model.fit(X = Var_Indep, y = Var_Dep)
# X debe ser mayúscula para la variable independiente
# Out:
# LinearRegression()

# %%
# Verificamos los coeficientes obtenidos para el modelo ajustado

model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['costo_total'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.7171753]),
#  'rank_': 1,
#  'singular_': array([121459.66134004]),
#  'intercept_': 632.0995299642545}

# %% [markdown]
# Modelo Matemático (Precio vs Costo Total): y = 0.7171753x1 + 632.0995299642545
